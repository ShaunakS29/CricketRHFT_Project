# %% [markdown]
# # INITIAL DATA CLEANING
# The data relating to the 2020 and 2021 seasons of the tournament was fetched mostly from cricsheet.org website and a few portions taken from Wikipedia. The data was in the form of comma-separated values(csv). Two sets of csv files were present. The first set contained a summary of each match with information on playing eleven, toss, winning team and winning margin. The second set contained the ball-by-ball data of every match that included the striker, non-striker, bowler, runs scored and wickets taken.

# %%
import numpy as np
import pandas as pd
import glob

# %%
# Get CSV files ending with info from folder
path = r'C:\Users\DELL\Cricdata\rhf'
csv_files = glob.glob(path + "/*info.csv")

# %%
# Read each CSV file into a list of dataframes

df_list = []

for file in csv_files:
    df = pd.read_csv(file,nrows=20,sep='\t',header=0)
    df_list.append(df)

# %%
df_list[1]
# Out:
#                                         version,2.2.0
# 0                               info,balls_per_over,6
# 1                          info,team,South East Stars
# 2                             info,team,Western Storm
# 3                                  info,gender,female
# 4                                    info,season,2020
# 5                                info,date,2020/08/29
# 6              info,event,Rachael Heyhoe Flint Trophy
# 7   info,venue,"Kent County Cricket Ground, Becken...
# 8                                 info,city,Beckenham
# 9                      info,toss_winner,Western Storm
# 10                           info,toss_decision,field
# 11                               info,umpire,NJ Llong
# 12                            info,umpire,SM Bartlett
# 13                         info,match_referee,PM Such
# 14                          info,winner,Western Storm
# 15                              info,winner_wickets,6
# 16              info,player,South East Stars,BF Smith
# 17              info,player,South East Stars,A Capsey
# 18           info,player,South East Stars,A Cranstone
# 19           info,player,South East Stars,SIR Dunkley

# %%
for i in range(len(df_list)):
    df_list[i]=df_list[i]['version,2.2.0'].str.split(",",expand=True) #split the columns comma wise

# %%
df_list[1]
# Out:
#        0               1                            2            3
# 0   info  balls_per_over                            6         None
# 1   info            team             South East Stars         None
# 2   info            team                Western Storm         None
# 3   info          gender                       female         None
# 4   info          season                         2020         None
# 5   info            date                   2020/08/29         None
# 6   info           event  Rachael Heyhoe Flint Trophy         None
# 7   info           venue  "Kent County Cricket Ground   Beckenham"
# 8   info            city                    Beckenham         None
# 9   info     toss_winner                Western Storm         None
# 10  info   toss_decision                        field         None
# 11  info          umpire                     NJ Llong         None
# 12  info          umpire                  SM Bartlett         None
# 13  info   match_referee                      PM Such         None
# 14  info          winner                Western Storm         None
# 15  info  winner_wickets                            6         None
# 16  info          player             South East Stars     BF Smith
# 17  info          player             South East Stars     A Capsey
# 18  info          player             South East Stars  A Cranstone
# 19  info          player             South East Stars  SIR Dunkley

# %%
for i in range(len(df_list)):
    df_list[i].drop([0,3],axis=1,inplace=True) #drop the first and last column

# %%
df_list[1]
# Out:
#                  1                            2
# 0   balls_per_over                            6
# 1             team             South East Stars
# 2             team                Western Storm
# 3           gender                       female
# 4           season                         2020
# 5             date                   2020/08/29
# 6            event  Rachael Heyhoe Flint Trophy
# 7            venue  "Kent County Cricket Ground
# 8             city                    Beckenham
# 9      toss_winner                Western Storm
# 10   toss_decision                        field
# 11          umpire                     NJ Llong
# 12          umpire                  SM Bartlett
# 13   match_referee                      PM Such
# 14          winner                Western Storm
# 15  winner_wickets                            6
# 16          player             South East Stars
# 17          player             South East Stars
# 18          player             South East Stars
# 19          player             South East Stars

# %%
#combine all the dataframes columnwise into one
match_summary = pd.concat(df_list,axis=1)

# %%
match_summary
# Out:
#                  1                            2               1  \
# 0   balls_per_over                            6  balls_per_over
# 1             team                    Sunrisers            team
# 2             team              Southern Vipers            team
# 3           gender                       female          gender
# 4           season                         2020          season
# 5             date                   2020/08/29            date
# 6            event  Rachael Heyhoe Flint Trophy           event
# 7            venue               "County Ground           venue
# 8             city                   Chelmsford            city
# 9      toss_winner              Southern Vipers     toss_winner
# 10   toss_decision                        field   toss_decision
# 11          umpire                    AY Harris          umpire
# 12          umpire                  Chris Watts          umpire
# 13   match_referee                     SJ Davis   match_referee
# 14          winner              Southern Vipers          winner
# 15  winner_wickets                            7  winner_wickets
# 16          player                    Sunrisers          player
# 17          player                    Sunrisers          player
# 18          player                    Sunrisers          player
# 19          player                    Sunrisers          player
#
#                               2               1                            2  \
# 0                             6  balls_per_over                            6
# 1              South East Stars            team              Southern Vipers
# 2                 Western Storm            team                Western Storm
# 3                        female          gender                       female
# 4                          2020          season                         2020
# 5                    2020/08/29            date                   2020/08/31
# 6   Rachael Heyhoe Flint Trophy           event  Rachael Heyhoe Flint Trophy
# 7   "Kent County Cricket Ground           venue               "County Ground
# 8                     Beckenham            city                      Bristol
# 9                 Western Storm     toss_winner                Western Storm
# 10                        field   toss_decision                        field
# 11                     NJ Llong          umpire                    JW Lloyds
# 12                  SM Bartlett          umpire             Y Dolphin-Cooper
# 13                      PM Such   match_referee                    DA Cosker
# 14                Western Storm          winner              Southern Vipers
# 15                            6     winner_runs                           22
# 16             South East Stars          player              Southern Vipers
# 17             South East Stars          player              Southern Vipers
# 18             South East Stars          player              Southern Vipers
# 19             South East Stars          player              Southern Vipers
#
#                  1                            2               1  \
# 0   balls_per_over                            6  balls_per_over
# 1             team             South East Stars            team
# 2             team                    Sunrisers            team
# 3           gender                       female          gender
# 4           season                         2020          season
# 5             date                   2020/08/31            date
# 6            event  Rachael Heyhoe Flint Trophy           event
# 7            venue  "Kent County Cricket Ground           venue
# 8             city                    Beckenham            city
# 9      toss_winner             South East Stars     toss_winner
# 10   toss_decision                          bat   toss_decision
# 11          umpire                     NJ Llong          umpire
# 12          umpire                  S McLelland          umpire
# 13   match_referee                     SJ Davis   match_referee
# 14          winner             South East Stars          winner
# 15     winner_runs                           77  winner_wickets
# 16          player             South East Stars          player
# 17          player             South East Stars          player
# 18          player             South East Stars          player
# 19          player             South East Stars          player
#
#                               2  ...               1  \
# 0                             6  ...  balls_per_over
# 1                       Thunder  ...            team
# 2                Central Sparks  ...            team
# 3                        female  ...          gender
# 4                          2020  ...          season
# 5                    2020/08/31  ...            date
# 6   Rachael Heyhoe Flint Trophy  ...           event
# 7                    "Edgbaston  ...           venue
# 8                    Birmingham  ...            city
# 9                       Thunder  ...     toss_winner
# 10                          bat  ...   toss_decision
# 11                  M Underdown  ...          umpire
# 12                    S Redfern  ...          umpire
# 13                     WR Smith  ...   match_referee
# 14               Central Sparks  ...          winner
# 15                            4  ...     winner_runs
# 16                      Thunder  ...          player
# 17                      Thunder  ...          player
# 18                      Thunder  ...          player
# 19                      Thunder  ...          player
#
#                               2               1                            2  \
# 0                             6  balls_per_over                            6
# 1                       Thunder            team                Western Storm
# 2              South East Stars            team                    Sunrisers
# 3                        female          gender                       female
# 4                          2021          season                         2021
# 5                    2021/09/18            date                   2021/09/18
# 6   Rachael Heyhoe Flint Trophy           event  Rachael Heyhoe Flint Trophy
# 7   "Kent County Cricket Ground           venue               "County Ground
# 8                     Beckenham            city                      Bristol
# 9                       Thunder     toss_winner                Western Storm
# 10                          bat   toss_decision                          bat
# 11                  Mark Newell          umpire                  Tom Lungley
# 12                  SM Bartlett          umpire             Y Dolphin-Cooper
# 13                   DE Malcolm   match_referee                     SG Hinks
# 14                      Thunder          winner                Western Storm
# 15                           55     winner_runs                           36
# 16                      Thunder          player                Western Storm
# 17                      Thunder          player                Western Storm
# 18                      Thunder          player                Western Storm
# 19                      Thunder          player                Western Storm
#
#                  1                            2               1  \
# 0   balls_per_over                            6  balls_per_over
# 1             team            Northern Diamonds            team
# 2             team              Southern Vipers            team
# 3           gender                       female          gender
# 4           season                         2021          season
# 5             date                   2021/09/18            date
# 6            event  Rachael Heyhoe Flint Trophy           event
# 7            venue               "The Rose Bowl           venue
# 8             city                  Southampton            city
# 9      toss_winner            Northern Diamonds     toss_winner
# 10   toss_decision                          bat   toss_decision
# 11          umpire                    IN Ramage          umpire
# 12          umpire                  S McLelland          umpire
# 13   match_referee                     AJ Swann   match_referee
# 14          winner              Southern Vipers          winner
# 15  winner_wickets                            5  winner_wickets
# 16          player            Northern Diamonds          player
# 17          player            Northern Diamonds          player
# 18          player            Northern Diamonds          player
# 19          player            Northern Diamonds          player
#
#                               2                1                            2
# 0                             6   balls_per_over                            6
# 1                Central Sparks             team            Northern Diamonds
# 2             Northern Diamonds             team              Southern Vipers
# 3                        female           gender                       female
# 4                          2021           season                         2021
# 5                    2021/09/22             date                   2021/09/25
# 6   Rachael Heyhoe Flint Trophy            event  Rachael Heyhoe Flint Trophy
# 7     "North Marine Road Ground            venue               "County Ground
# 8                   Scarborough             city                  Northampton
# 9                Central Sparks      toss_winner            Northern Diamonds
# 10                          bat    toss_decision                          bat
# 11                    Rob White  player_of_match                    E Windsor
# 12                  SM Bartlett           umpire                      J Naeem
# 13                     AW Smith           umpire                      N Pratt
# 14            Northern Diamonds   reserve_umpire                  S McLelland
# 15                            6    match_referee                  JJ Whitaker
# 16               Central Sparks           winner              Southern Vipers
# 17               Central Sparks   winner_wickets                            3
# 18               Central Sparks           player            Northern Diamonds
# 19               Central Sparks           player            Northern Diamonds
#
# [20 rows x 110 columns]

# %%
#reset the column headers
match_summary.columns = range(match_summary.columns.size)

# %%
match_summary
# Out:
#                0                            1               2    \
# 0   balls_per_over                            6  balls_per_over
# 1             team                    Sunrisers            team
# 2             team              Southern Vipers            team
# 3           gender                       female          gender
# 4           season                         2020          season
# 5             date                   2020/08/29            date
# 6            event  Rachael Heyhoe Flint Trophy           event
# 7            venue               "County Ground           venue
# 8             city                   Chelmsford            city
# 9      toss_winner              Southern Vipers     toss_winner
# 10   toss_decision                        field   toss_decision
# 11          umpire                    AY Harris          umpire
# 12          umpire                  Chris Watts          umpire
# 13   match_referee                     SJ Davis   match_referee
# 14          winner              Southern Vipers          winner
# 15  winner_wickets                            7  winner_wickets
# 16          player                    Sunrisers          player
# 17          player                    Sunrisers          player
# 18          player                    Sunrisers          player
# 19          player                    Sunrisers          player
#
#                             3               4                            5    \
# 0                             6  balls_per_over                            6
# 1              South East Stars            team              Southern Vipers
# 2                 Western Storm            team                Western Storm
# 3                        female          gender                       female
# 4                          2020          season                         2020
# 5                    2020/08/29            date                   2020/08/31
# 6   Rachael Heyhoe Flint Trophy           event  Rachael Heyhoe Flint Trophy
# 7   "Kent County Cricket Ground           venue               "County Ground
# 8                     Beckenham            city                      Bristol
# 9                 Western Storm     toss_winner                Western Storm
# 10                        field   toss_decision                        field
# 11                     NJ Llong          umpire                    JW Lloyds
# 12                  SM Bartlett          umpire             Y Dolphin-Cooper
# 13                      PM Such   match_referee                    DA Cosker
# 14                Western Storm          winner              Southern Vipers
# 15                            6     winner_runs                           22
# 16             South East Stars          player              Southern Vipers
# 17             South East Stars          player              Southern Vipers
# 18             South East Stars          player              Southern Vipers
# 19             South East Stars          player              Southern Vipers
#
#                6                            7               8    \
# 0   balls_per_over                            6  balls_per_over
# 1             team             South East Stars            team
# 2             team                    Sunrisers            team
# 3           gender                       female          gender
# 4           season                         2020          season
# 5             date                   2020/08/31            date
# 6            event  Rachael Heyhoe Flint Trophy           event
# 7            venue  "Kent County Cricket Ground           venue
# 8             city                    Beckenham            city
# 9      toss_winner             South East Stars     toss_winner
# 10   toss_decision                          bat   toss_decision
# 11          umpire                     NJ Llong          umpire
# 12          umpire                  S McLelland          umpire
# 13   match_referee                     SJ Davis   match_referee
# 14          winner             South East Stars          winner
# 15     winner_runs                           77  winner_wickets
# 16          player             South East Stars          player
# 17          player             South East Stars          player
# 18          player             South East Stars          player
# 19          player             South East Stars          player
#
#                             9    ...             100  \
# 0                             6  ...  balls_per_over
# 1                       Thunder  ...            team
# 2                Central Sparks  ...            team
# 3                        female  ...          gender
# 4                          2020  ...          season
# 5                    2020/08/31  ...            date
# 6   Rachael Heyhoe Flint Trophy  ...           event
# 7                    "Edgbaston  ...           venue
# 8                    Birmingham  ...            city
# 9                       Thunder  ...     toss_winner
# 10                          bat  ...   toss_decision
# 11                  M Underdown  ...          umpire
# 12                    S Redfern  ...          umpire
# 13                     WR Smith  ...   match_referee
# 14               Central Sparks  ...          winner
# 15                            4  ...     winner_runs
# 16                      Thunder  ...          player
# 17                      Thunder  ...          player
# 18                      Thunder  ...          player
# 19                      Thunder  ...          player
#
#                             101             102                          103  \
# 0                             6  balls_per_over                            6
# 1                       Thunder            team                Western Storm
# 2              South East Stars            team                    Sunrisers
# 3                        female          gender                       female
# 4                          2021          season                         2021
# 5                    2021/09/18            date                   2021/09/18
# 6   Rachael Heyhoe Flint Trophy           event  Rachael Heyhoe Flint Trophy
# 7   "Kent County Cricket Ground           venue               "County Ground
# 8                     Beckenham            city                      Bristol
# 9                       Thunder     toss_winner                Western Storm
# 10                          bat   toss_decision                          bat
# 11                  Mark Newell          umpire                  Tom Lungley
# 12                  SM Bartlett          umpire             Y Dolphin-Cooper
# 13                   DE Malcolm   match_referee                     SG Hinks
# 14                      Thunder          winner                Western Storm
# 15                           55     winner_runs                           36
# 16                      Thunder          player                Western Storm
# 17                      Thunder          player                Western Storm
# 18                      Thunder          player                Western Storm
# 19                      Thunder          player                Western Storm
#
#                104                          105             106  \
# 0   balls_per_over                            6  balls_per_over
# 1             team            Northern Diamonds            team
# 2             team              Southern Vipers            team
# 3           gender                       female          gender
# 4           season                         2021          season
# 5             date                   2021/09/18            date
# 6            event  Rachael Heyhoe Flint Trophy           event
# 7            venue               "The Rose Bowl           venue
# 8             city                  Southampton            city
# 9      toss_winner            Northern Diamonds     toss_winner
# 10   toss_decision                          bat   toss_decision
# 11          umpire                    IN Ramage          umpire
# 12          umpire                  S McLelland          umpire
# 13   match_referee                     AJ Swann   match_referee
# 14          winner              Southern Vipers          winner
# 15  winner_wickets                            5  winner_wickets
# 16          player            Northern Diamonds          player
# 17          player            Northern Diamonds          player
# 18          player            Northern Diamonds          player
# 19          player            Northern Diamonds          player
#
#                             107              108                          109
# 0                             6   balls_per_over                            6
# 1                Central Sparks             team            Northern Diamonds
# 2             Northern Diamonds             team              Southern Vipers
# 3                        female           gender                       female
# 4                          2021           season                         2021
# 5                    2021/09/22             date                   2021/09/25
# 6   Rachael Heyhoe Flint Trophy            event  Rachael Heyhoe Flint Trophy
# 7     "North Marine Road Ground            venue               "County Ground
# 8                   Scarborough             city                  Northampton
# 9                Central Sparks      toss_winner            Northern Diamonds
# 10                          bat    toss_decision                          bat
# 11                    Rob White  player_of_match                    E Windsor
# 12                  SM Bartlett           umpire                      J Naeem
# 13                     AW Smith           umpire                      N Pratt
# 14            Northern Diamonds   reserve_umpire                  S McLelland
# 15                            6    match_referee                  JJ Whitaker
# 16               Central Sparks           winner              Southern Vipers
# 17               Central Sparks   winner_wickets                            3
# 18               Central Sparks           player            Northern Diamonds
# 19               Central Sparks           player            Northern Diamonds
#
# [20 rows x 110 columns]

# %%
#transpose the dataframe
match_summary=match_summary.T

# %%
match_summary
# Out:
#                  0                  1                  2       3       4   \
# 0    balls_per_over               team               team  gender  season
# 1                 6          Sunrisers    Southern Vipers  female    2020
# 2    balls_per_over               team               team  gender  season
# 3                 6   South East Stars      Western Storm  female    2020
# 4    balls_per_over               team               team  gender  season
# ..              ...                ...                ...     ...     ...
# 105               6  Northern Diamonds    Southern Vipers  female    2021
# 106  balls_per_over               team               team  gender  season
# 107               6     Central Sparks  Northern Diamonds  female    2021
# 108  balls_per_over               team               team  gender  season
# 109               6  Northern Diamonds    Southern Vipers  female    2021
#
#              5                            6                            7   \
# 0          date                        event                        venue
# 1    2020/08/29  Rachael Heyhoe Flint Trophy               "County Ground
# 2          date                        event                        venue
# 3    2020/08/29  Rachael Heyhoe Flint Trophy  "Kent County Cricket Ground
# 4          date                        event                        venue
# ..          ...                          ...                          ...
# 105  2021/09/18  Rachael Heyhoe Flint Trophy               "The Rose Bowl
# 106        date                        event                        venue
# 107  2021/09/22  Rachael Heyhoe Flint Trophy    "North Marine Road Ground
# 108        date                        event                        venue
# 109  2021/09/25  Rachael Heyhoe Flint Trophy               "County Ground
#
#               8                  9              10               11  \
# 0           city        toss_winner  toss_decision           umpire
# 1     Chelmsford    Southern Vipers          field        AY Harris
# 2           city        toss_winner  toss_decision           umpire
# 3      Beckenham      Western Storm          field         NJ Llong
# 4           city        toss_winner  toss_decision           umpire
# ..           ...                ...            ...              ...
# 105  Southampton  Northern Diamonds            bat        IN Ramage
# 106         city        toss_winner  toss_decision           umpire
# 107  Scarborough     Central Sparks            bat        Rob White
# 108         city        toss_winner  toss_decision  player_of_match
# 109  Northampton  Northern Diamonds            bat        E Windsor
#
#               12             13                 14              15  \
# 0         umpire  match_referee             winner  winner_wickets
# 1    Chris Watts       SJ Davis    Southern Vipers               7
# 2         umpire  match_referee             winner  winner_wickets
# 3    SM Bartlett        PM Such      Western Storm               6
# 4         umpire  match_referee             winner     winner_runs
# ..           ...            ...                ...             ...
# 105  S McLelland       AJ Swann    Southern Vipers               5
# 106       umpire  match_referee             winner  winner_wickets
# 107  SM Bartlett       AW Smith  Northern Diamonds               6
# 108       umpire         umpire     reserve_umpire   match_referee
# 109      J Naeem        N Pratt        S McLelland     JJ Whitaker
#
#                     16                 17                 18  \
# 0               player             player             player
# 1            Sunrisers          Sunrisers          Sunrisers
# 2               player             player             player
# 3     South East Stars   South East Stars   South East Stars
# 4               player             player             player
# ..                 ...                ...                ...
# 105  Northern Diamonds  Northern Diamonds  Northern Diamonds
# 106             player             player             player
# 107     Central Sparks     Central Sparks     Central Sparks
# 108             winner     winner_wickets             player
# 109    Southern Vipers                  3  Northern Diamonds
#
#                     19
# 0               player
# 1            Sunrisers
# 2               player
# 3     South East Stars
# 4               player
# ..                 ...
# 105  Northern Diamonds
# 106             player
# 107     Central Sparks
# 108             player
# 109  Northern Diamonds
#
# [110 rows x 20 columns]

# %%
#check out values of certain columns
for i in (0,3,6,7,11,12,13,16,17,18,19):
    print(match_summary[i].value_counts())
    print("\n")
# Out:
# balls_per_over    53
# 6                 53
# Name: 0, dtype: int64
#
#
# female    53
# gender    53
# Name: 3, dtype: int64
#
#
# event                          53
# Rachael Heyhoe Flint Trophy    53
# Name: 6, dtype: int64
#
#
# venue                                   53
# "County Ground                          18
# "Kent County Cricket Ground              5
# "Headingley                              4
#  Worcester"                              4
# "The Rose Bowl                           4
# "Riverside Ground                        3
# "Edgbaston                               3
# "Aigburth                                2
# "Grace Road                              2
# "Kennington Oval                         2
# "Boughton Hall Cricket Club Ground       2
# "Haslegrave Ground                       2
# "North Marine Road Ground                1
# "FP Fenner's Ground                      1
# "Merchant Taylors' School Ground         1
# Kibworth Cricket Club Ground             1
# "The Cooper Associates County Ground     1
# "Rookwood                                1
# Name: 7, dtype: int64
#
#
# umpire               47
# player_of_match       6
# J Naeem               6
# J Ibbotson            5
# Mark Newell           4
# Hassan Adnan          4
# Rob White             3
# AY Harris             3
# IN Ramage             3
# M Underdown           2
# L Nenova              2
# James Middlebrook     2
# S McLelland           2
# NJ Llong              2
# JW Lloyds             2
# CM Taylor             1
# E Windsor             1
# S Redfern             1
# Tom Lungley           1
# FMK Morris            1
# BV Taylor             1
# F Richards            1
# GA Elwiss             1
# GL Adams              1
# SM Bartlett           1
# N Pratt               1
# A Capsey              1
# NA Mallender          1
# Name: 11, dtype: int64
#
#
# umpire              53
# Y Dolphin-Cooper     8
# SM Bartlett          8
# Tom Lungley          4
# S McLelland          4
# N Pratt              4
# S Redfern            4
# J Naeem              3
# J Ibbotson           3
# Mark Newell          3
# Chris Watts          2
# L Nenova             2
# PJ Hartley           1
# BJ Debenham          1
# IN Ramage            1
# M Underdown          1
# M Burns              1
# PR Pollard           1
# AY Harris            1
# SJ O'Shaughnessy     1
# Name: 12, dtype: int64
#
#
# match_referee        44
# umpire                6
# Phil Whitticase       5
# DW Headley            5
# WR Smith              4
# SJ Davis              4
# AJ Swann              3
# JJ Whitaker           3
# DA Cosker             3
# winner                3
# SG Hinks              3
# S Cummings            3
# AW Smith              2
# DE Malcolm            2
# TJ Boon               2
# Southern Vipers       2
# S McLelland           2
# F Richards            1
# N Pratt               1
# Rob White             1
# S Laister             1
# Northern Diamonds     1
# RM Ellison            1
# GR Cowdrey            1
# Alastair Smith        1
# PM Such               1
# NJ Llong              1
# Name: 13, dtype: int64
#
#
# player               46
# Thunder               8
# South East Stars      8
# Northern Diamonds     7
# Lightning             6
# Western Storm         5
# Central Sparks        5
# Southern Vipers       5
# Sunrisers             3
# winner_runs           2
# winner_wickets        2
# 6                     1
# D/L                   1
# method                1
# 1                     1
# winner                1
# 8                     1
# SJ Davis              1
# 86                    1
# match_referee         1
# Name: 16, dtype: int64
#
#
# player               51
# Thunder               8
# South East Stars      8
# Western Storm         7
# Northern Diamonds     7
# Southern Vipers       6
# Lightning             6
# Sunrisers             5
# Central Sparks        5
# winner                1
# 3                     1
# winner_wickets        1
# Name: 17, dtype: int64
#
#
# player               52
# Northern Diamonds     8
# Thunder               8
# South East Stars      8
# Western Storm         7
# Lightning             6
# Sunrisers             5
# Central Sparks        5
# Southern Vipers       5
# winner_runs           1
# 38                    1
# Name: 18, dtype: int64
#
#
# player               53
# Northern Diamonds     8
# Thunder               8
# South East Stars      8
# Western Storm         7
# Southern Vipers       6
# Lightning             6
# Sunrisers             5
# Central Sparks        5
# Name: 19, dtype: int64

# %%
#remove initial columns that do not contain any uselful value
match_summary.drop([0,3,6,7,11,12,19],axis=1,inplace=True)
#reset the column headers
match_summary.columns = range(match_summary.columns.size)
match_summary
# Out:
#                     0                  1       2           3            4   \
# 0                 team               team  season        date         city
# 1            Sunrisers    Southern Vipers    2020  2020/08/29   Chelmsford
# 2                 team               team  season        date         city
# 3     South East Stars      Western Storm    2020  2020/08/29    Beckenham
# 4                 team               team  season        date         city
# ..                 ...                ...     ...         ...          ...
# 105  Northern Diamonds    Southern Vipers    2021  2021/09/18  Southampton
# 106               team               team  season        date         city
# 107     Central Sparks  Northern Diamonds    2021  2021/09/22  Scarborough
# 108               team               team  season        date         city
# 109  Northern Diamonds    Southern Vipers    2021  2021/09/25  Northampton
#
#                     5              6              7                  8   \
# 0          toss_winner  toss_decision  match_referee             winner
# 1      Southern Vipers          field       SJ Davis    Southern Vipers
# 2          toss_winner  toss_decision  match_referee             winner
# 3        Western Storm          field        PM Such      Western Storm
# 4          toss_winner  toss_decision  match_referee             winner
# ..                 ...            ...            ...                ...
# 105  Northern Diamonds            bat       AJ Swann    Southern Vipers
# 106        toss_winner  toss_decision  match_referee             winner
# 107     Central Sparks            bat       AW Smith  Northern Diamonds
# 108        toss_winner  toss_decision         umpire     reserve_umpire
# 109  Northern Diamonds            bat        N Pratt        S McLelland
#
#                  9                  10                 11                 12
# 0    winner_wickets             player             player             player
# 1                 7          Sunrisers          Sunrisers          Sunrisers
# 2    winner_wickets             player             player             player
# 3                 6   South East Stars   South East Stars   South East Stars
# 4       winner_runs             player             player             player
# ..              ...                ...                ...                ...
# 105               5  Northern Diamonds  Northern Diamonds  Northern Diamonds
# 106  winner_wickets             player             player             player
# 107               6     Central Sparks     Central Sparks     Central Sparks
# 108   match_referee             winner     winner_wickets             player
# 109     JJ Whitaker    Southern Vipers                  3  Northern Diamonds
#
# [110 rows x 13 columns]

# %%
#rename some columns
match_summary.rename(columns = {0:'Team1',1:'Team2',2:'Season',3:'Date',4:'Venue',5:'Toss_Winner',
                               6:'Toss_Decision',8:'Winner',9:'Winning_Margin'}, inplace = True)

# %%
match_summary
# Out:
#                  Team1              Team2  Season        Date        Venue  \
# 0                 team               team  season        date         city
# 1            Sunrisers    Southern Vipers    2020  2020/08/29   Chelmsford
# 2                 team               team  season        date         city
# 3     South East Stars      Western Storm    2020  2020/08/29    Beckenham
# 4                 team               team  season        date         city
# ..                 ...                ...     ...         ...          ...
# 105  Northern Diamonds    Southern Vipers    2021  2021/09/18  Southampton
# 106               team               team  season        date         city
# 107     Central Sparks  Northern Diamonds    2021  2021/09/22  Scarborough
# 108               team               team  season        date         city
# 109  Northern Diamonds    Southern Vipers    2021  2021/09/25  Northampton
#
#            Toss_Winner  Toss_Decision              7             Winner  \
# 0          toss_winner  toss_decision  match_referee             winner
# 1      Southern Vipers          field       SJ Davis    Southern Vipers
# 2          toss_winner  toss_decision  match_referee             winner
# 3        Western Storm          field        PM Such      Western Storm
# 4          toss_winner  toss_decision  match_referee             winner
# ..                 ...            ...            ...                ...
# 105  Northern Diamonds            bat       AJ Swann    Southern Vipers
# 106        toss_winner  toss_decision  match_referee             winner
# 107     Central Sparks            bat       AW Smith  Northern Diamonds
# 108        toss_winner  toss_decision         umpire     reserve_umpire
# 109  Northern Diamonds            bat        N Pratt        S McLelland
#
#      Winning_Margin                 10                 11                 12
# 0    winner_wickets             player             player             player
# 1                 7          Sunrisers          Sunrisers          Sunrisers
# 2    winner_wickets             player             player             player
# 3                 6   South East Stars   South East Stars   South East Stars
# 4       winner_runs             player             player             player
# ..              ...                ...                ...                ...
# 105               5  Northern Diamonds  Northern Diamonds  Northern Diamonds
# 106  winner_wickets             player             player             player
# 107               6     Central Sparks     Central Sparks     Central Sparks
# 108   match_referee             winner     winner_wickets             player
# 109     JJ Whitaker    Southern Vipers                  3  Northern Diamonds
#
# [110 rows x 13 columns]

# %%
#check out values of column 'Winner'
match_summary['Winner'].value_counts()
# Out:
# winner               44
# Northern Diamonds     9
# Central Sparks        8
# Southern Vipers       8
# Western Storm         6
# Lightning             5
# match_referee         4
# Thunder               4
# South East Stars      4
# winner_runs           2
# reserve_umpire        2
# winner_wickets        1
# 7                     1
# AJ Swann              1
# 49                    1
# 111                   1
# DW Headley            1
# PM Such               1
# SM Bartlett           1
# S Cummings            1
# S McLelland           1
# Name: Winner, dtype: int64

# %%
#get index of rows where column 'Winner' has unusual values
check_rows=[]
check_rows.append(match_summary.index[match_summary['Winner']=='match_referee'].tolist())
check_rows.append(match_summary.index[match_summary['Winner']=='reserve_umpire'].tolist())
check_rows.append(match_summary.index[match_summary['Winner']=='SM Bartlett'].tolist())
check_rows.append(match_summary.index[match_summary['Winner']=='111'].tolist())
check_rows.append(match_summary.index[match_summary['Winner']=='DW Headley'].tolist())
check_rows.append(match_summary.index[match_summary['Winner']=='49'].tolist())
check_rows.append(match_summary.index[match_summary['Winner']=='winner_wickets'].tolist())
check_rows.append(match_summary.index[match_summary['Winner']=='7'].tolist())
check_rows.append(match_summary.index[match_summary['Winner']=='PM Such'].tolist())
check_rows.append(match_summary.index[match_summary['Winner']=='S McLelland'].tolist())
check_rows.append(match_summary.index[match_summary['Winner']=='S Cummings'].tolist())
check_rows.append(match_summary.index[match_summary['Winner']=='AJ Swann'].tolist())
#flatten the list for easyness
check_rows = list(np.concatenate(check_rows).flat)
#sort the list
check_rows.sort()
check_rows
# Out:
# [15, 16, 20, 26, 32, 33, 46, 47, 79, 80, 81, 82, 96, 97, 108, 109]

# %%
#investigating those particular rows
match_summary.iloc[check_rows]
# Out:
#                  Team1              Team2  Season        Date  \
# 15                team               team  season        date
# 16       Western Storm          Sunrisers    2020  2020/09/05
# 20     Southern Vipers   South East Stars    2020  2020/09/05
# 26     Southern Vipers          Sunrisers    2020  2020/09/11
# 32                team               team  season        date
# 33           Sunrisers   South East Stars    2020  2020/09/13
# 46                team               team  season        date
# 47     Southern Vipers  Northern Diamonds    2020  2020/09/27
# 79                team               team  season        date
# 80       Western Storm    Southern Vipers    2021  2021/06/12
# 81                team               team  season        date
# 82       Western Storm  Northern Diamonds    2021  2021/09/10
# 96                team               team  season        date
# 97     Southern Vipers          Sunrisers    2021  2021/09/12
# 108               team               team  season        date
# 109  Northern Diamonds    Southern Vipers    2021  2021/09/25
#
#                  Venue        Toss_Winner  Toss_Decision                  7  \
# 15                city        toss_winner  toss_decision             umpire
# 16          Chelmsford          Sunrisers          field           NJ Llong
# 20            Brighton    Southern Vipers            bat    Southern Vipers
# 26         Southampton    Southern Vipers            bat    Southern Vipers
# 32                city        toss_winner  toss_decision             umpire
# 33          Chelmsford          Sunrisers            bat         F Richards
# 46                city        toss_winner  toss_decision             umpire
# 47          Birmingham  Northern Diamonds          field          Rob White
# 79                city        toss_winner  toss_decision             umpire
# 80             Taunton      Western Storm            bat        S McLelland
# 81                city        toss_winner  toss_decision             winner
# 82   Chester-le-Street  Northern Diamonds          field  Northern Diamonds
# 96                city        toss_winner  toss_decision             umpire
# 97          Chelmsford          Sunrisers          field        S McLelland
# 108               city        toss_winner  toss_decision             umpire
# 109        Northampton  Northern Diamonds            bat            N Pratt
#
#              Winner     Winning_Margin               10               11  \
# 15    match_referee             winner      winner_runs           player
# 16          PM Such      Western Storm               86    Western Storm
# 20              111    Southern Vipers  Southern Vipers  Southern Vipers
# 26               49    Southern Vipers  Southern Vipers  Southern Vipers
# 32    match_referee             winner   winner_wickets           player
# 33         AJ Swann   South East Stars                6        Sunrisers
# 46   reserve_umpire          tv_umpire    match_referee           winner
# 47      SM Bartlett  James Middlebrook         SJ Davis  Southern Vipers
# 79    match_referee             winner   winner_wickets           player
# 80       S Cummings    Southern Vipers                8    Western Storm
# 81   winner_wickets             player           player           player
# 82                7      Western Storm    Western Storm    Western Storm
# 96    match_referee             winner      winner_runs           player
# 97       DW Headley    Southern Vipers                1  Southern Vipers
# 108  reserve_umpire      match_referee           winner   winner_wickets
# 109     S McLelland        JJ Whitaker  Southern Vipers                3
#
#                     12
# 15              player
# 16       Western Storm
# 20     Southern Vipers
# 26     Southern Vipers
# 32              player
# 33           Sunrisers
# 46         winner_runs
# 47                  38
# 79              player
# 80       Western Storm
# 81              player
# 82       Western Storm
# 96              player
# 97     Southern Vipers
# 108             player
# 109  Northern Diamonds

# %%
#correcting values for concerned rows
match_summary['Winner'].iloc[15] = 'winner'
match_summary['Winner'].iloc[16]= 'Western Storm'
match_summary['Winning_Margin'].iloc[15] = 'winner_runs'
match_summary['Winning_Margin'].iloc[16] = 86

match_summary['Winner'].iloc[32] = 'winner'
match_summary['Winner'].iloc[33] = 'South East Stars'
match_summary['Winning_Margin'].iloc[32] = 'winner_wickets'
match_summary['Winning_Margin'].iloc[33] = 6

match_summary['Winner'].iloc[46] = 'winner'
match_summary['Winner'].iloc[47] = 'Southern Vipers'
match_summary['Winning_Margin'].iloc[46] = 'winner_runs'
match_summary['Winning_Margin'].iloc[47] = 38

match_summary['Winner'].iloc[79] = 'winner'
match_summary['Winner'].iloc[80] = 'Southern Vipers'
match_summary['Winning_Margin'].iloc[79] = 'winner_wickets'
match_summary['Winning_Margin'].iloc[80] = 8

match_summary['Winner'].iloc[81] = 'winner'
match_summary['Winner'].iloc[82]= 'Northern Diamonds'
match_summary['Winning_Margin'].iloc[81] = 'winner_wickets'
match_summary['Winning_Margin'].iloc[82]= 7

match_summary['Winner'].iloc[96] = 'winner'
match_summary['Winner'].iloc[97] = 'Southern Vipers'
match_summary['Winning_Margin'].iloc[96] = 'winner_runs'
match_summary['Winning_Margin'].iloc[97] = 1

match_summary['Winner'].iloc[108] = 'winner'
match_summary['Winner'].iloc[109] = 'Southern Vipers'
match_summary['Winning_Margin'].iloc[108] = 'winner_wickets'
match_summary['Winning_Margin'].iloc[109] = 3

# %%
#checking those particular rows
match_summary.iloc[check_rows]
# Out:
#                  Team1              Team2  Season        Date  \
# 15                team               team  season        date
# 16       Western Storm          Sunrisers    2020  2020/09/05
# 20     Southern Vipers   South East Stars    2020  2020/09/05
# 26     Southern Vipers          Sunrisers    2020  2020/09/11
# 32                team               team  season        date
# 33           Sunrisers   South East Stars    2020  2020/09/13
# 46                team               team  season        date
# 47     Southern Vipers  Northern Diamonds    2020  2020/09/27
# 79                team               team  season        date
# 80       Western Storm    Southern Vipers    2021  2021/06/12
# 81                team               team  season        date
# 82       Western Storm  Northern Diamonds    2021  2021/09/10
# 96                team               team  season        date
# 97     Southern Vipers          Sunrisers    2021  2021/09/12
# 108               team               team  season        date
# 109  Northern Diamonds    Southern Vipers    2021  2021/09/25
#
#                  Venue        Toss_Winner  Toss_Decision                  7  \
# 15                city        toss_winner  toss_decision             umpire
# 16          Chelmsford          Sunrisers          field           NJ Llong
# 20            Brighton    Southern Vipers            bat    Southern Vipers
# 26         Southampton    Southern Vipers            bat    Southern Vipers
# 32                city        toss_winner  toss_decision             umpire
# 33          Chelmsford          Sunrisers            bat         F Richards
# 46                city        toss_winner  toss_decision             umpire
# 47          Birmingham  Northern Diamonds          field          Rob White
# 79                city        toss_winner  toss_decision             umpire
# 80             Taunton      Western Storm            bat        S McLelland
# 81                city        toss_winner  toss_decision             winner
# 82   Chester-le-Street  Northern Diamonds          field  Northern Diamonds
# 96                city        toss_winner  toss_decision             umpire
# 97          Chelmsford          Sunrisers          field        S McLelland
# 108               city        toss_winner  toss_decision             umpire
# 109        Northampton  Northern Diamonds            bat            N Pratt
#
#                 Winner   Winning_Margin               10               11  \
# 15              winner      winner_runs      winner_runs           player
# 16       Western Storm               86               86    Western Storm
# 20                 111  Southern Vipers  Southern Vipers  Southern Vipers
# 26                  49  Southern Vipers  Southern Vipers  Southern Vipers
# 32              winner   winner_wickets   winner_wickets           player
# 33    South East Stars                6                6        Sunrisers
# 46              winner      winner_runs    match_referee           winner
# 47     Southern Vipers               38         SJ Davis  Southern Vipers
# 79              winner   winner_wickets   winner_wickets           player
# 80     Southern Vipers                8                8    Western Storm
# 81              winner   winner_wickets           player           player
# 82   Northern Diamonds                7    Western Storm    Western Storm
# 96              winner      winner_runs      winner_runs           player
# 97     Southern Vipers                1                1  Southern Vipers
# 108             winner   winner_wickets           winner   winner_wickets
# 109    Southern Vipers                3  Southern Vipers                3
#
#                     12
# 15              player
# 16       Western Storm
# 20     Southern Vipers
# 26     Southern Vipers
# 32              player
# 33           Sunrisers
# 46         winner_runs
# 47                  38
# 79              player
# 80       Western Storm
# 81              player
# 82       Western Storm
# 96              player
# 97     Southern Vipers
# 108             player
# 109  Northern Diamonds

# %%
#investigating rows 19 20 25 26
match_summary.iloc[[19,20,25,26]]
# Out:
#               Team1             Team2  Season        Date        Venue  \
# 19             team              team  season        date         city
# 20  Southern Vipers  South East Stars    2020  2020/09/05     Brighton
# 25             team              team  season        date         city
# 26  Southern Vipers         Sunrisers    2020  2020/09/11  Southampton
#
#         Toss_Winner  Toss_Decision                7       Winner  \
# 19      toss_winner  toss_decision           winner  winner_runs
# 20  Southern Vipers            bat  Southern Vipers          111
# 25      toss_winner  toss_decision           winner  winner_runs
# 26  Southern Vipers            bat  Southern Vipers           49
#
#      Winning_Margin               10               11               12
# 19           player           player           player           player
# 20  Southern Vipers  Southern Vipers  Southern Vipers  Southern Vipers
# 25           player           player           player           player
# 26  Southern Vipers  Southern Vipers  Southern Vipers  Southern Vipers

# %%
#correcting values for concerned rows
match_summary['Winner'].iloc[19] = 'winner'
match_summary['Winner'].iloc[20] = 'Southern Vipers'
match_summary['Winning_Margin'].iloc[19] = 'winner_runs'
match_summary['Winning_Margin'].iloc[20] = 111

match_summary['Winner'].iloc[25] = 'winner'
match_summary['Winner'].iloc[26]= 'Southern Vipers'
match_summary['Winning_Margin'].iloc[25] = 'winner_runs'
match_summary['Winning_Margin'].iloc[26] = 49

# %%
#checking rows 19 20 25 26
match_summary.iloc[[19,20,25,26]]
# Out:
#               Team1             Team2  Season        Date        Venue  \
# 19             team              team  season        date         city
# 20  Southern Vipers  South East Stars    2020  2020/09/05     Brighton
# 25             team              team  season        date         city
# 26  Southern Vipers         Sunrisers    2020  2020/09/11  Southampton
#
#         Toss_Winner  Toss_Decision                7           Winner  \
# 19      toss_winner  toss_decision           winner           winner
# 20  Southern Vipers            bat  Southern Vipers  Southern Vipers
# 25      toss_winner  toss_decision           winner           winner
# 26  Southern Vipers            bat  Southern Vipers  Southern Vipers
#
#    Winning_Margin               10               11               12
# 19    winner_runs           player           player           player
# 20            111  Southern Vipers  Southern Vipers  Southern Vipers
# 25    winner_runs           player           player           player
# 26             49  Southern Vipers  Southern Vipers  Southern Vipers

# %%
#check out values of column 'Winner'
match_summary['Winner'].value_counts()
# Out:
# winner               53
# Southern Vipers      14
# Northern Diamonds    10
# Central Sparks        8
# Western Storm         7
# South East Stars      5
# Lightning             5
# Thunder               4
# Name: Winner, dtype: int64

# %%
#check out values of column 'Winning_Margin'
match_summary['Winning_Margin'].value_counts()
# Out:
# winner_runs       27
# winner_wickets    26
# 6                  8
# 2                  3
# 7                  3
# 4                  3
# 5                  2
# 55                 2
# 3                  2
# 36                 2
# 9                  2
# 38                 1
# 8                  1
# 1                  1
# 47                 1
# 28                 1
# 111                1
# 8                  1
# 49                 1
# 62                 1
# 134                1
# 77                 1
# 120                1
# 72                 1
# 135                1
# 3                  1
# 105                1
# 86                 1
# 22                 1
# 24                 1
# 73                 1
# 1                  1
# 41                 1
# 7                  1
# 6                  1
# 32                 1
# 115                1
# Name: Winning_Margin, dtype: int64

# %%
#remove other columns that do not contain any uselful value
match_summary.drop([7,10,11,12],axis=1,inplace=True)

# %%
match_summary
# Out:
#                  Team1              Team2  Season        Date        Venue  \
# 0                 team               team  season        date         city
# 1            Sunrisers    Southern Vipers    2020  2020/08/29   Chelmsford
# 2                 team               team  season        date         city
# 3     South East Stars      Western Storm    2020  2020/08/29    Beckenham
# 4                 team               team  season        date         city
# ..                 ...                ...     ...         ...          ...
# 105  Northern Diamonds    Southern Vipers    2021  2021/09/18  Southampton
# 106               team               team  season        date         city
# 107     Central Sparks  Northern Diamonds    2021  2021/09/22  Scarborough
# 108               team               team  season        date         city
# 109  Northern Diamonds    Southern Vipers    2021  2021/09/25  Northampton
#
#            Toss_Winner  Toss_Decision             Winner  Winning_Margin
# 0          toss_winner  toss_decision             winner  winner_wickets
# 1      Southern Vipers          field    Southern Vipers               7
# 2          toss_winner  toss_decision             winner  winner_wickets
# 3        Western Storm          field      Western Storm               6
# 4          toss_winner  toss_decision             winner     winner_runs
# ..                 ...            ...                ...             ...
# 105  Northern Diamonds            bat    Southern Vipers               5
# 106        toss_winner  toss_decision             winner  winner_wickets
# 107     Central Sparks            bat  Northern Diamonds               6
# 108        toss_winner  toss_decision             winner  winner_wickets
# 109  Northern Diamonds            bat    Southern Vipers               3
#
# [110 rows x 9 columns]

# %%
#Add new column ByWickets
match_summary['ByWickets']=match_summary['Winning_Margin'].apply(lambda x: 'Y' if x == 'winner_wickets' else 'N')

# %%
#Add new column ByRuns
match_summary['ByRuns']=match_summary['Winning_Margin'].apply(lambda x: 'Y' if x == 'winner_runs' else 'N')

# %%
match_summary
# Out:
#                  Team1              Team2  Season        Date        Venue  \
# 0                 team               team  season        date         city
# 1            Sunrisers    Southern Vipers    2020  2020/08/29   Chelmsford
# 2                 team               team  season        date         city
# 3     South East Stars      Western Storm    2020  2020/08/29    Beckenham
# 4                 team               team  season        date         city
# ..                 ...                ...     ...         ...          ...
# 105  Northern Diamonds    Southern Vipers    2021  2021/09/18  Southampton
# 106               team               team  season        date         city
# 107     Central Sparks  Northern Diamonds    2021  2021/09/22  Scarborough
# 108               team               team  season        date         city
# 109  Northern Diamonds    Southern Vipers    2021  2021/09/25  Northampton
#
#            Toss_Winner  Toss_Decision             Winner  Winning_Margin  \
# 0          toss_winner  toss_decision             winner  winner_wickets
# 1      Southern Vipers          field    Southern Vipers               7
# 2          toss_winner  toss_decision             winner  winner_wickets
# 3        Western Storm          field      Western Storm               6
# 4          toss_winner  toss_decision             winner     winner_runs
# ..                 ...            ...                ...             ...
# 105  Northern Diamonds            bat    Southern Vipers               5
# 106        toss_winner  toss_decision             winner  winner_wickets
# 107     Central Sparks            bat  Northern Diamonds               6
# 108        toss_winner  toss_decision             winner  winner_wickets
# 109  Northern Diamonds            bat    Southern Vipers               3
#
#     ByWickets ByRuns
# 0           Y      N
# 1           N      N
# 2           Y      N
# 3           N      N
# 4           N      Y
# ..        ...    ...
# 105         N      N
# 106         Y      N
# 107         N      N
# 108         Y      N
# 109         N      N
#
# [110 rows x 11 columns]

# %%
#locate next row positions to put ByWickets value
next_rows=[]
next_rows.append(match_summary.index[match_summary['ByWickets']=='Y'].tolist())
next_rows=np.add(next_rows, 1).tolist()
next_rows
# Out:
# [[1,
#   3,
#   9,
#   13,
#   18,
#   24,
#   33,
#   37,
#   39,
#   41,
#   49,
#   51,
#   55,
#   61,
#   65,
#   67,
#   73,
#   75,
#   77,
#   80,
#   82,
#   86,
#   88,
#   105,
#   107,
#   109]]

# %%
#flatten the list
next_rows=list(np.concatenate(next_rows).flat)

# %%
#change the values
match_summary['ByWickets'].iloc[next_rows] = 'Y'

# %%
match_summary
# Out:
#                  Team1              Team2  Season        Date        Venue  \
# 0                 team               team  season        date         city
# 1            Sunrisers    Southern Vipers    2020  2020/08/29   Chelmsford
# 2                 team               team  season        date         city
# 3     South East Stars      Western Storm    2020  2020/08/29    Beckenham
# 4                 team               team  season        date         city
# ..                 ...                ...     ...         ...          ...
# 105  Northern Diamonds    Southern Vipers    2021  2021/09/18  Southampton
# 106               team               team  season        date         city
# 107     Central Sparks  Northern Diamonds    2021  2021/09/22  Scarborough
# 108               team               team  season        date         city
# 109  Northern Diamonds    Southern Vipers    2021  2021/09/25  Northampton
#
#            Toss_Winner  Toss_Decision             Winner  Winning_Margin  \
# 0          toss_winner  toss_decision             winner  winner_wickets
# 1      Southern Vipers          field    Southern Vipers               7
# 2          toss_winner  toss_decision             winner  winner_wickets
# 3        Western Storm          field      Western Storm               6
# 4          toss_winner  toss_decision             winner     winner_runs
# ..                 ...            ...                ...             ...
# 105  Northern Diamonds            bat    Southern Vipers               5
# 106        toss_winner  toss_decision             winner  winner_wickets
# 107     Central Sparks            bat  Northern Diamonds               6
# 108        toss_winner  toss_decision             winner  winner_wickets
# 109  Northern Diamonds            bat    Southern Vipers               3
#
#     ByWickets ByRuns
# 0           Y      N
# 1           Y      N
# 2           Y      N
# 3           Y      N
# 4           N      Y
# ..        ...    ...
# 105         Y      N
# 106         Y      N
# 107         Y      N
# 108         Y      N
# 109         Y      N
#
# [110 rows x 11 columns]

# %%
#Likewise locate and modify next row positions to put ByRuns value
next_rows=[]
next_rows.append(match_summary.index[match_summary['ByRuns']=='Y'].tolist())
next_rows=np.add(next_rows, 1).tolist()
next_rows=list(np.concatenate(next_rows).flat)
match_summary['ByRuns'].iloc[next_rows] = 'Y'

# %%
match_summary.head(10)
# Out:
#               Team1            Team2  Season        Date       Venue  \
# 0              team             team  season        date        city
# 1         Sunrisers  Southern Vipers    2020  2020/08/29  Chelmsford
# 2              team             team  season        date        city
# 3  South East Stars    Western Storm    2020  2020/08/29   Beckenham
# 4              team             team  season        date        city
# 5   Southern Vipers    Western Storm    2020  2020/08/31     Bristol
# 6              team             team  season        date        city
# 7  South East Stars        Sunrisers    2020  2020/08/31   Beckenham
# 8              team             team  season        date        city
# 9           Thunder   Central Sparks    2020  2020/08/31  Birmingham
#
#         Toss_Winner  Toss_Decision            Winner  Winning_Margin  \
# 0       toss_winner  toss_decision            winner  winner_wickets
# 1   Southern Vipers          field   Southern Vipers               7
# 2       toss_winner  toss_decision            winner  winner_wickets
# 3     Western Storm          field     Western Storm               6
# 4       toss_winner  toss_decision            winner     winner_runs
# 5     Western Storm          field   Southern Vipers              22
# 6       toss_winner  toss_decision            winner     winner_runs
# 7  South East Stars            bat  South East Stars              77
# 8       toss_winner  toss_decision            winner  winner_wickets
# 9           Thunder            bat    Central Sparks               4
#
#   ByWickets ByRuns
# 0         Y      N
# 1         Y      N
# 2         Y      N
# 3         Y      N
# 4         N      Y
# 5         N      Y
# 6         N      Y
# 7         N      Y
# 8         Y      N
# 9         Y      N

# %%
#remove the irrelevant rows
drop_rows = []
drop_rows.append(match_summary.index[match_summary['Team1']=='team'].tolist())
drop_rows=list(np.concatenate(drop_rows).flat)
match_summary.drop(drop_rows,axis=0,inplace=True)

# %%
match_summary.reset_index(drop=True,inplace=True)

# %%
match_summary
# Out:
#                 Team1              Team2 Season        Date  \
# 0           Sunrisers    Southern Vipers   2020  2020/08/29
# 1    South East Stars      Western Storm   2020  2020/08/29
# 2     Southern Vipers      Western Storm   2020  2020/08/31
# 3    South East Stars          Sunrisers   2020  2020/08/31
# 4             Thunder     Central Sparks   2020  2020/08/31
# 5   Northern Diamonds          Lightning   2020  2020/08/31
# 6             Thunder     Central Sparks   2020  2020/09/05
# 7                None               None   None        None
# 8       Western Storm          Sunrisers   2020  2020/09/05
# 9           Lightning  Northern Diamonds   2020  2020/09/05
# 10    Southern Vipers   South East Stars   2020  2020/09/05
# 11  Northern Diamonds            Thunder   2020  2020/09/10
# 12   South East Stars      Western Storm   2020  2020/09/11
# 13    Southern Vipers          Sunrisers   2020  2020/09/11
# 14          Lightning     Central Sparks   2020  2020/09/11
# 15               None               None   None        None
# 16    Southern Vipers      Western Storm   2020  2020/09/13
# 17          Sunrisers   South East Stars   2020  2020/09/13
# 18            Thunder          Lightning   2020  2020/09/13
# 19  Northern Diamonds     Central Sparks   2020  2020/09/13
# 20   South East Stars    Southern Vipers   2020  2020/09/19
# 21            Thunder  Northern Diamonds   2020  2020/09/19
# 22          Lightning     Central Sparks   2020  2020/09/19
# 23      Western Storm          Sunrisers   2020  2020/09/19
# 24    Southern Vipers  Northern Diamonds   2020  2020/09/27
# 25  Northern Diamonds     Central Sparks   2021  2021/05/29
# 26            Thunder      Western Storm   2021  2021/05/29
# 27   South East Stars          Sunrisers   2021  2021/05/29
# 28          Lightning    Southern Vipers   2021  2021/05/29
# 29  Northern Diamonds          Lightning   2021  2021/05/31
# 30     Central Sparks      Western Storm   2021  2021/05/31
# 31   South East Stars    Southern Vipers   2021  2021/05/31
# 32            Thunder          Sunrisers   2021  2021/05/31
# 33      Western Storm   South East Stars   2021  2021/06/05
# 34          Sunrisers  Northern Diamonds   2021  2021/06/05
# 35          Lightning            Thunder   2021  2021/06/06
# 36     Central Sparks    Southern Vipers   2021  2021/06/05
# 37   South East Stars  Northern Diamonds   2021  2021/06/12
# 38          Sunrisers          Lightning   2021  2021/06/12
# 39     Central Sparks            Thunder   2021  2021/06/12
# 40               None               None   None        None
# 41      Western Storm    Southern Vipers   2021  2021/06/12
# 42      Western Storm  Northern Diamonds   2021  2021/09/10
# 43   South East Stars          Lightning   2021  2021/09/10
# 44          Sunrisers     Central Sparks   2021  2021/09/10
# 45            Thunder    Southern Vipers   2021  2021/09/10
# 46  Northern Diamonds            Thunder   2021  2021/09/12
# 47     Central Sparks   South East Stars   2021  2021/09/12
# 48               None               None   None        None
# 49      Western Storm          Lightning   2021  2021/09/12
# 50    Southern Vipers          Sunrisers   2021  2021/09/12
# 51          Lightning     Central Sparks   2021  2021/09/18
# 52            Thunder   South East Stars   2021  2021/09/18
# 53      Western Storm          Sunrisers   2021  2021/09/18
# 54  Northern Diamonds    Southern Vipers   2021  2021/09/18
# 55     Central Sparks  Northern Diamonds   2021  2021/09/22
# 56  Northern Diamonds    Southern Vipers   2021  2021/09/25
#
#                 Venue        Toss_Winner Toss_Decision             Winner  \
# 0          Chelmsford    Southern Vipers         field    Southern Vipers
# 1           Beckenham      Western Storm         field      Western Storm
# 2             Bristol      Western Storm         field    Southern Vipers
# 3           Beckenham   South East Stars           bat   South East Stars
# 4          Birmingham            Thunder           bat     Central Sparks
# 5   Chester-le-Street  Northern Diamonds           bat  Northern Diamonds
# 6           Worcester            Thunder           bat     Central Sparks
# 7                None               None          None               None
# 8          Chelmsford          Sunrisers         field      Western Storm
# 9           Leicester  Northern Diamonds         field  Northern Diamonds
# 10           Brighton    Southern Vipers           bat    Southern Vipers
# 11          Liverpool            Thunder         field  Northern Diamonds
# 12            Bristol   South East Stars           bat      Western Storm
# 13        Southampton    Southern Vipers           bat    Southern Vipers
# 14          Worcester     Central Sparks         field          Lightning
# 15               None               None          None               None
# 16        Southampton    Southern Vipers           bat    Southern Vipers
# 17         Chelmsford          Sunrisers           bat   South East Stars
# 18          Liverpool            Thunder           bat            Thunder
# 19              Leeds  Northern Diamonds           bat     Central Sparks
# 20             London   South East Stars           bat    Southern Vipers
# 21              Leeds            Thunder           bat  Northern Diamonds
# 22          Leicester     Central Sparks         field          Lightning
# 23            Bristol          Sunrisers         field      Western Storm
# 24         Birmingham  Northern Diamonds         field    Southern Vipers
# 25              Leeds     Central Sparks         field     Central Sparks
# 26            Bristol      Western Storm         field      Western Storm
# 27         Chelmsford          Sunrisers         field   South East Stars
# 28        Southampton          Lightning           bat    Southern Vipers
# 29           Kibworth          Lightning         field  Northern Diamonds
# 30         Birmingham      Western Storm         field     Central Sparks
# 31          Beckenham    Southern Vipers         field    Southern Vipers
# 32            Chester            Thunder           bat            Thunder
# 33             London   South East Stars         field   South East Stars
# 34          Cambridge  Northern Diamonds         field  Northern Diamonds
# 35            Chester          Lightning           bat          Lightning
# 36           Brighton     Central Sparks           bat     Central Sparks
# 37              Leeds   South East Stars           bat  Northern Diamonds
# 38       Loughborough          Sunrisers           bat          Lightning
# 39          Worcester     Central Sparks           bat            Thunder
# 40               None               None          None               None
# 41            Taunton      Western Storm           bat    Southern Vipers
# 42  Chester-le-Street  Northern Diamonds         field  Northern Diamonds
# 43          Beckenham   South East Stars           bat   South East Stars
# 44          Northwood     Central Sparks         field     Central Sparks
# 45               Sale    Southern Vipers         field    Southern Vipers
# 46  Chester-le-Street            Thunder         field  Northern Diamonds
# 47          Worcester     Central Sparks           bat     Central Sparks
# 48               None               None          None               None
# 49            Bristol          Lightning         field      Western Storm
# 50         Chelmsford          Sunrisers         field    Southern Vipers
# 51       Loughborough     Central Sparks         field          Lightning
# 52          Beckenham            Thunder           bat            Thunder
# 53            Bristol      Western Storm           bat      Western Storm
# 54        Southampton  Northern Diamonds           bat    Southern Vipers
# 55        Scarborough     Central Sparks           bat  Northern Diamonds
# 56        Northampton  Northern Diamonds           bat    Southern Vipers
#
#    Winning_Margin ByWickets ByRuns
# 0               7         Y      N
# 1               6         Y      N
# 2              22         N      Y
# 3              77         N      Y
# 4               4         Y      N
# 5               9         N      Y
# 6               8         Y      N
# 7            None         N      N
# 8              86         N      Y
# 9               2         Y      N
# 10            111         N      Y
# 11             73         N      Y
# 12              7         Y      N
# 13             49         N      Y
# 14              6         N      Y
# 15           None         N      N
# 16             32         N      Y
# 17              6         Y      N
# 18             72         N      Y
# 19              6         Y      N
# 20              4         Y      N
# 21              6         Y      N
# 22             55         N      Y
# 23             47         N      Y
# 24             38         N      Y
# 25              2         Y      N
# 26              1         Y      N
# 27            135         N      Y
# 28              4         Y      N
# 29              6         N      Y
# 30             41         N      Y
# 31              7         Y      N
# 32             36         N      Y
# 33              6         Y      N
# 34              9         Y      N
# 35            134         N      Y
# 36            120         N      Y
# 37              3         Y      N
# 38              5         Y      N
# 39              2         Y      N
# 40           None         N      N
# 41              8         Y      N
# 42              7         Y      N
# 43             28         N      Y
# 44              6         Y      N
# 45              3         Y      N
# 46            105         N      Y
# 47            115         N      Y
# 48           None         N      N
# 49             62         N      Y
# 50              1         N      Y
# 51             24         N      Y
# 52             55         N      Y
# 53             36         N      Y
# 54              5         Y      N
# 55              6         Y      N
# 56              3         Y      N

# %%
#remove the None values
match_summary = match_summary.replace(to_replace='None', value=np.nan).dropna()
match_summary.reset_index(drop=True,inplace=True)

# %%
match_summary
# Out:
#                 Team1              Team2 Season        Date  \
# 0           Sunrisers    Southern Vipers   2020  2020/08/29
# 1    South East Stars      Western Storm   2020  2020/08/29
# 2     Southern Vipers      Western Storm   2020  2020/08/31
# 3    South East Stars          Sunrisers   2020  2020/08/31
# 4             Thunder     Central Sparks   2020  2020/08/31
# 5   Northern Diamonds          Lightning   2020  2020/08/31
# 6             Thunder     Central Sparks   2020  2020/09/05
# 7       Western Storm          Sunrisers   2020  2020/09/05
# 8           Lightning  Northern Diamonds   2020  2020/09/05
# 9     Southern Vipers   South East Stars   2020  2020/09/05
# 10  Northern Diamonds            Thunder   2020  2020/09/10
# 11   South East Stars      Western Storm   2020  2020/09/11
# 12    Southern Vipers          Sunrisers   2020  2020/09/11
# 13          Lightning     Central Sparks   2020  2020/09/11
# 14    Southern Vipers      Western Storm   2020  2020/09/13
# 15          Sunrisers   South East Stars   2020  2020/09/13
# 16            Thunder          Lightning   2020  2020/09/13
# 17  Northern Diamonds     Central Sparks   2020  2020/09/13
# 18   South East Stars    Southern Vipers   2020  2020/09/19
# 19            Thunder  Northern Diamonds   2020  2020/09/19
# 20          Lightning     Central Sparks   2020  2020/09/19
# 21      Western Storm          Sunrisers   2020  2020/09/19
# 22    Southern Vipers  Northern Diamonds   2020  2020/09/27
# 23  Northern Diamonds     Central Sparks   2021  2021/05/29
# 24            Thunder      Western Storm   2021  2021/05/29
# 25   South East Stars          Sunrisers   2021  2021/05/29
# 26          Lightning    Southern Vipers   2021  2021/05/29
# 27  Northern Diamonds          Lightning   2021  2021/05/31
# 28     Central Sparks      Western Storm   2021  2021/05/31
# 29   South East Stars    Southern Vipers   2021  2021/05/31
# 30            Thunder          Sunrisers   2021  2021/05/31
# 31      Western Storm   South East Stars   2021  2021/06/05
# 32          Sunrisers  Northern Diamonds   2021  2021/06/05
# 33          Lightning            Thunder   2021  2021/06/06
# 34     Central Sparks    Southern Vipers   2021  2021/06/05
# 35   South East Stars  Northern Diamonds   2021  2021/06/12
# 36          Sunrisers          Lightning   2021  2021/06/12
# 37     Central Sparks            Thunder   2021  2021/06/12
# 38      Western Storm    Southern Vipers   2021  2021/06/12
# 39      Western Storm  Northern Diamonds   2021  2021/09/10
# 40   South East Stars          Lightning   2021  2021/09/10
# 41          Sunrisers     Central Sparks   2021  2021/09/10
# 42            Thunder    Southern Vipers   2021  2021/09/10
# 43  Northern Diamonds            Thunder   2021  2021/09/12
# 44     Central Sparks   South East Stars   2021  2021/09/12
# 45      Western Storm          Lightning   2021  2021/09/12
# 46    Southern Vipers          Sunrisers   2021  2021/09/12
# 47          Lightning     Central Sparks   2021  2021/09/18
# 48            Thunder   South East Stars   2021  2021/09/18
# 49      Western Storm          Sunrisers   2021  2021/09/18
# 50  Northern Diamonds    Southern Vipers   2021  2021/09/18
# 51     Central Sparks  Northern Diamonds   2021  2021/09/22
# 52  Northern Diamonds    Southern Vipers   2021  2021/09/25
#
#                 Venue        Toss_Winner Toss_Decision             Winner  \
# 0          Chelmsford    Southern Vipers         field    Southern Vipers
# 1           Beckenham      Western Storm         field      Western Storm
# 2             Bristol      Western Storm         field    Southern Vipers
# 3           Beckenham   South East Stars           bat   South East Stars
# 4          Birmingham            Thunder           bat     Central Sparks
# 5   Chester-le-Street  Northern Diamonds           bat  Northern Diamonds
# 6           Worcester            Thunder           bat     Central Sparks
# 7          Chelmsford          Sunrisers         field      Western Storm
# 8           Leicester  Northern Diamonds         field  Northern Diamonds
# 9            Brighton    Southern Vipers           bat    Southern Vipers
# 10          Liverpool            Thunder         field  Northern Diamonds
# 11            Bristol   South East Stars           bat      Western Storm
# 12        Southampton    Southern Vipers           bat    Southern Vipers
# 13          Worcester     Central Sparks         field          Lightning
# 14        Southampton    Southern Vipers           bat    Southern Vipers
# 15         Chelmsford          Sunrisers           bat   South East Stars
# 16          Liverpool            Thunder           bat            Thunder
# 17              Leeds  Northern Diamonds           bat     Central Sparks
# 18             London   South East Stars           bat    Southern Vipers
# 19              Leeds            Thunder           bat  Northern Diamonds
# 20          Leicester     Central Sparks         field          Lightning
# 21            Bristol          Sunrisers         field      Western Storm
# 22         Birmingham  Northern Diamonds         field    Southern Vipers
# 23              Leeds     Central Sparks         field     Central Sparks
# 24            Bristol      Western Storm         field      Western Storm
# 25         Chelmsford          Sunrisers         field   South East Stars
# 26        Southampton          Lightning           bat    Southern Vipers
# 27           Kibworth          Lightning         field  Northern Diamonds
# 28         Birmingham      Western Storm         field     Central Sparks
# 29          Beckenham    Southern Vipers         field    Southern Vipers
# 30            Chester            Thunder           bat            Thunder
# 31             London   South East Stars         field   South East Stars
# 32          Cambridge  Northern Diamonds         field  Northern Diamonds
# 33            Chester          Lightning           bat          Lightning
# 34           Brighton     Central Sparks           bat     Central Sparks
# 35              Leeds   South East Stars           bat  Northern Diamonds
# 36       Loughborough          Sunrisers           bat          Lightning
# 37          Worcester     Central Sparks           bat            Thunder
# 38            Taunton      Western Storm           bat    Southern Vipers
# 39  Chester-le-Street  Northern Diamonds         field  Northern Diamonds
# 40          Beckenham   South East Stars           bat   South East Stars
# 41          Northwood     Central Sparks         field     Central Sparks
# 42               Sale    Southern Vipers         field    Southern Vipers
# 43  Chester-le-Street            Thunder         field  Northern Diamonds
# 44          Worcester     Central Sparks           bat     Central Sparks
# 45            Bristol          Lightning         field      Western Storm
# 46         Chelmsford          Sunrisers         field    Southern Vipers
# 47       Loughborough     Central Sparks         field          Lightning
# 48          Beckenham            Thunder           bat            Thunder
# 49            Bristol      Western Storm           bat      Western Storm
# 50        Southampton  Northern Diamonds           bat    Southern Vipers
# 51        Scarborough     Central Sparks           bat  Northern Diamonds
# 52        Northampton  Northern Diamonds           bat    Southern Vipers
#
#    Winning_Margin ByWickets ByRuns
# 0               7         Y      N
# 1               6         Y      N
# 2              22         N      Y
# 3              77         N      Y
# 4               4         Y      N
# 5               9         N      Y
# 6               8         Y      N
# 7              86         N      Y
# 8               2         Y      N
# 9             111         N      Y
# 10             73         N      Y
# 11              7         Y      N
# 12             49         N      Y
# 13              6         N      Y
# 14             32         N      Y
# 15              6         Y      N
# 16             72         N      Y
# 17              6         Y      N
# 18              4         Y      N
# 19              6         Y      N
# 20             55         N      Y
# 21             47         N      Y
# 22             38         N      Y
# 23              2         Y      N
# 24              1         Y      N
# 25            135         N      Y
# 26              4         Y      N
# 27              6         N      Y
# 28             41         N      Y
# 29              7         Y      N
# 30             36         N      Y
# 31              6         Y      N
# 32              9         Y      N
# 33            134         N      Y
# 34            120         N      Y
# 35              3         Y      N
# 36              5         Y      N
# 37              2         Y      N
# 38              8         Y      N
# 39              7         Y      N
# 40             28         N      Y
# 41              6         Y      N
# 42              3         Y      N
# 43            105         N      Y
# 44            115         N      Y
# 45             62         N      Y
# 46              1         N      Y
# 47             24         N      Y
# 48             55         N      Y
# 49             36         N      Y
# 50              5         Y      N
# 51              6         Y      N
# 52              3         Y      N

# %%
#finally export the dataframe to csv file
match_summary.to_csv("C:\\Users\\DELL\\Cricdata\\match_summary.csv",index=False)

# %%
allmatch_df = pd.read_csv('C:\\Users\\DELL\\Cricdata\\rhf\\all_matches.csv')

# %%
allmatch_df.head()
# Out:
#    match_id  season  start_date                      venue  innings  ball  \
# 0   1229326    2020  2020-08-29  County Ground, Chelmsford        1   0.1
# 1   1229326    2020  2020-08-29  County Ground, Chelmsford        1   0.2
# 2   1229326    2020  2020-08-29  County Ground, Chelmsford        1   0.3
# 3   1229326    2020  2020-08-29  County Ground, Chelmsford        1   0.4
# 4   1229326    2020  2020-08-29  County Ground, Chelmsford        1   0.5
#
#   batting_team     bowling_team     striker non_striker  ... extras  wides  \
# 0    Sunrisers  Southern Vipers  KL Midwood     AD Carr  ...      0    NaN
# 1    Sunrisers  Southern Vipers  KL Midwood     AD Carr  ...      0    NaN
# 2    Sunrisers  Southern Vipers  KL Midwood     AD Carr  ...      0    NaN
# 3    Sunrisers  Southern Vipers  KL Midwood     AD Carr  ...      1    1.0
# 4    Sunrisers  Southern Vipers  KL Midwood     AD Carr  ...      1    1.0
#
#    noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# 0      NaN   NaN      NaN      NaN          NaN               NaN
# 1      NaN   NaN      NaN      NaN          NaN               NaN
# 2      NaN   NaN      NaN      NaN          NaN               NaN
# 3      NaN   NaN      NaN      NaN          NaN               NaN
# 4      NaN   NaN      NaN      NaN          NaN               NaN
#
#   other_wicket_type other_player_dismissed
# 0               NaN                    NaN
# 1               NaN                    NaN
# 2               NaN                    NaN
# 3               NaN                    NaN
# 4               NaN                    NaN
#
# [5 rows x 22 columns]

# %%
allmatch_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30228 entries, 0 to 30227
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   match_id                30228 non-null  int64
#  1   season                  30228 non-null  int64
#  2   start_date              30228 non-null  object
#  3   venue                   30228 non-null  object
#  4   innings                 30228 non-null  int64
#  5   ball                    30228 non-null  float64
#  6   batting_team            30228 non-null  object
#  7   bowling_team            30228 non-null  object
#  8   striker                 30228 non-null  object
#  9   non_striker             30228 non-null  object
#  10  bowler                  30228 non-null  object
#  11  runs_off_bat            30228 non-null  int64
#  12  extras                  30228 non-null  int64
#  13  wides                   1341 non-null   float64
#  14  noballs                 114 non-null    float64
#  15  byes                    77 non-null     float64
#  16  legbyes                 313 non-null    float64
#  17  penalty                 1 non-null      float64
#  18  wicket_type             828 non-null    object
#  19  player_dismissed        828 non-null    object
#  20  other_wicket_type       0 non-null      float64
#  21  other_player_dismissed  0 non-null      float64
# dtypes: float64(8), int64(5), object(9)
# memory usage: 5.1+ MB

# %%
#drop columns that contain no or only a single value
allmatch_df.drop(['penalty','other_wicket_type','other_player_dismissed'],axis=1,inplace=True)

# %%
allmatch_df.head()
# Out:
#    match_id  season  start_date                      venue  innings  ball  \
# 0   1229326    2020  2020-08-29  County Ground, Chelmsford        1   0.1
# 1   1229326    2020  2020-08-29  County Ground, Chelmsford        1   0.2
# 2   1229326    2020  2020-08-29  County Ground, Chelmsford        1   0.3
# 3   1229326    2020  2020-08-29  County Ground, Chelmsford        1   0.4
# 4   1229326    2020  2020-08-29  County Ground, Chelmsford        1   0.5
#
#   batting_team     bowling_team     striker non_striker   bowler  \
# 0    Sunrisers  Southern Vipers  KL Midwood     AD Carr  LK Bell
# 1    Sunrisers  Southern Vipers  KL Midwood     AD Carr  LK Bell
# 2    Sunrisers  Southern Vipers  KL Midwood     AD Carr  LK Bell
# 3    Sunrisers  Southern Vipers  KL Midwood     AD Carr  LK Bell
# 4    Sunrisers  Southern Vipers  KL Midwood     AD Carr  LK Bell
#
#    runs_off_bat  extras  wides  noballs  byes  legbyes wicket_type  \
# 0             0       0    NaN      NaN   NaN      NaN         NaN
# 1             0       0    NaN      NaN   NaN      NaN         NaN
# 2             0       0    NaN      NaN   NaN      NaN         NaN
# 3             0       1    1.0      NaN   NaN      NaN         NaN
# 4             0       1    1.0      NaN   NaN      NaN         NaN
#
#   player_dismissed
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
#check unique values of venue
allmatch_df['venue'].value_counts()
# Out:
# County Ground, Bristol                          3642
# County Ground, Chelmsford                       2899
# Kent County Cricket Ground, Beckenham           2711
# The Rose Bowl, Southampton                      2428
# County Ground, New Road, Worcester              2315
# Headingley, Leeds                               2300
# Edgbaston, Birmingham                           1772
# Riverside Ground, Chester-le-Street             1682
# Grace Road, Leicester                           1261
# Aigburth, Liverpool                             1206
# Haslegrave Ground, Loughborough                 1200
# Kennington Oval, London                         1188
# Boughton Hall Cricket Club Ground, Chester      1161
# County Ground, Hove                             1029
# County Ground, Northampton                       621
# Kibworth Cricket Club Ground                     592
# The Cooper Associates County Ground, Taunton     535
# North Marine Road Ground, Scarborough            524
# Merchant Taylors' School Ground, Northwood       507
# Rookwood, Sale                                   415
# FP Fenner's Ground, Cambridge                    240
# Name: venue, dtype: int64

# %%
# find the match_id where venue is Kibworth Cricket Club Ground
allmatch_df[allmatch_df['venue']=='Kibworth Cricket Club Ground']['match_id'].unique()
# Out:
# array([1252268], dtype=int64)

# %%
#modify the value of venue
allmatch_df['venue'][allmatch_df['match_id']==1252268] = 'Kibworth Cricket Club Ground,Kibworth'
# Out:
# <ipython-input-54-f3186ee439d7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allmatch_df['venue'][allmatch_df['match_id']==1252268] = 'Kibworth Cricket Club Ground,Kibworth'

# %%
# find the match_id where venue is County Ground, New Road, Worcester
allmatch_df[allmatch_df['venue']=='County Ground, New Road, Worcester']['match_id'].unique()
# Out:
# array([1229334, 1229341, 1252278, 1252285], dtype=int64)

# %%
#modify the value of venue
allmatch_df['venue'][allmatch_df['match_id'] == 1229334] = 'County Ground, Worcester'
allmatch_df['venue'][allmatch_df['match_id'] == 1229341] = 'County Ground, Worcester'
allmatch_df['venue'][allmatch_df['match_id'] == 1252278] = 'County Ground, Worcester'
allmatch_df['venue'][allmatch_df['match_id'] == 1252285] = 'County Ground, Worcester'
# Out:
# <ipython-input-56-a57da79b7e65>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allmatch_df['venue'][allmatch_df['match_id'] == 1229334] = 'County Ground, Worcester'
# <ipython-input-56-a57da79b7e65>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allmatch_df['venue'][allmatch_df['match_id'] == 1229341] = 'County Ground, Worcester'
# <ipython-input-56-a57da79b7e65>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allmatch_df['venue'][allmatch_df['match_id'] == 1252278] = 'County Ground, Worcester'
# <ipython-input-56-a57da79b7e65>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allmatch_df['venue'][allmatch_df['match_id'] == 1252285] = 'County Ground, Worcester'

# %%
#check unique values of venue
allmatch_df['venue'].value_counts()
# Out:
# County Ground, Bristol                          3642
# County Ground, Chelmsford                       2899
# Kent County Cricket Ground, Beckenham           2711
# The Rose Bowl, Southampton                      2428
# County Ground, Worcester                        2315
# Headingley, Leeds                               2300
# Edgbaston, Birmingham                           1772
# Riverside Ground, Chester-le-Street             1682
# Grace Road, Leicester                           1261
# Aigburth, Liverpool                             1206
# Haslegrave Ground, Loughborough                 1200
# Kennington Oval, London                         1188
# Boughton Hall Cricket Club Ground, Chester      1161
# County Ground, Hove                             1029
# County Ground, Northampton                       621
# Kibworth Cricket Club Ground,Kibworth            592
# The Cooper Associates County Ground, Taunton     535
# North Marine Road Ground, Scarborough            524
# Merchant Taylors' School Ground, Northwood       507
# Rookwood, Sale                                   415
# FP Fenner's Ground, Cambridge                    240
# Name: venue, dtype: int64

# %%
#split the venue column comma wise
allmatch_df['venue'].str.split(",",expand=True)
# Out:
#                    0             1
# 0      County Ground    Chelmsford
# 1      County Ground    Chelmsford
# 2      County Ground    Chelmsford
# 3      County Ground    Chelmsford
# 4      County Ground    Chelmsford
# ...              ...           ...
# 30223  County Ground   Northampton
# 30224  County Ground   Northampton
# 30225  County Ground   Northampton
# 30226  County Ground   Northampton
# 30227  County Ground   Northampton
#
# [30228 rows x 2 columns]

# %%
#keep only the city name
allmatch_df['venue']=allmatch_df['venue'].str.split(",",expand=True)[1]
allmatch_df['venue']=allmatch_df['venue'].str.strip() #remove extra space

# %%
allmatch_df.head()
# Out:
#    match_id  season  start_date       venue  innings  ball batting_team  \
# 0   1229326    2020  2020-08-29  Chelmsford        1   0.1    Sunrisers
# 1   1229326    2020  2020-08-29  Chelmsford        1   0.2    Sunrisers
# 2   1229326    2020  2020-08-29  Chelmsford        1   0.3    Sunrisers
# 3   1229326    2020  2020-08-29  Chelmsford        1   0.4    Sunrisers
# 4   1229326    2020  2020-08-29  Chelmsford        1   0.5    Sunrisers
#
#       bowling_team     striker non_striker   bowler  runs_off_bat  extras  \
# 0  Southern Vipers  KL Midwood     AD Carr  LK Bell             0       0
# 1  Southern Vipers  KL Midwood     AD Carr  LK Bell             0       0
# 2  Southern Vipers  KL Midwood     AD Carr  LK Bell             0       0
# 3  Southern Vipers  KL Midwood     AD Carr  LK Bell             0       1
# 4  Southern Vipers  KL Midwood     AD Carr  LK Bell             0       1
#
#    wides  noballs  byes  legbyes wicket_type player_dismissed
# 0    NaN      NaN   NaN      NaN         NaN              NaN
# 1    NaN      NaN   NaN      NaN         NaN              NaN
# 2    NaN      NaN   NaN      NaN         NaN              NaN
# 3    1.0      NaN   NaN      NaN         NaN              NaN
# 4    1.0      NaN   NaN      NaN         NaN              NaN

# %%
allmatch_df['venue'].value_counts()
# Out:
# Bristol              3642
# Chelmsford           2899
# Beckenham            2711
# Southampton          2428
# Worcester            2315
# Leeds                2300
# Birmingham           1772
# Chester-le-Street    1682
# Leicester            1261
# Liverpool            1206
# Loughborough         1200
# London               1188
# Chester              1161
# Hove                 1029
# Northampton           621
# Kibworth              592
# Taunton               535
# Scarborough           524
# Northwood             507
# Sale                  415
# Cambridge             240
# Name: venue, dtype: int64

# %%
#add a new column 'over'
import math
allmatch_df['over']=allmatch_df['ball'].apply(np.ceil)

# %%
allmatch_df['over']=allmatch_df['over'].astype(int)

# %%
allmatch_df.head(10)
# Out:
#    match_id  season  start_date       venue  innings  ball batting_team  \
# 0   1229326    2020  2020-08-29  Chelmsford        1   0.1    Sunrisers
# 1   1229326    2020  2020-08-29  Chelmsford        1   0.2    Sunrisers
# 2   1229326    2020  2020-08-29  Chelmsford        1   0.3    Sunrisers
# 3   1229326    2020  2020-08-29  Chelmsford        1   0.4    Sunrisers
# 4   1229326    2020  2020-08-29  Chelmsford        1   0.5    Sunrisers
# 5   1229326    2020  2020-08-29  Chelmsford        1   0.6    Sunrisers
# 6   1229326    2020  2020-08-29  Chelmsford        1   0.7    Sunrisers
# 7   1229326    2020  2020-08-29  Chelmsford        1   0.8    Sunrisers
# 8   1229326    2020  2020-08-29  Chelmsford        1   0.9    Sunrisers
# 9   1229326    2020  2020-08-29  Chelmsford        1   1.1    Sunrisers
#
#       bowling_team     striker non_striker     bowler  runs_off_bat  extras  \
# 0  Southern Vipers  KL Midwood     AD Carr    LK Bell             0       0
# 1  Southern Vipers  KL Midwood     AD Carr    LK Bell             0       0
# 2  Southern Vipers  KL Midwood     AD Carr    LK Bell             0       0
# 3  Southern Vipers  KL Midwood     AD Carr    LK Bell             0       1
# 4  Southern Vipers  KL Midwood     AD Carr    LK Bell             0       1
# 5  Southern Vipers  KL Midwood     AD Carr    LK Bell             0       1
# 6  Southern Vipers  KL Midwood     AD Carr    LK Bell             0       0
# 7  Southern Vipers  KL Midwood     AD Carr    LK Bell             0       0
# 8  Southern Vipers  KL Midwood     AD Carr    LK Bell             0       0
# 9  Southern Vipers     AD Carr  KL Midwood  TG Norris             0       0
#
#    wides  noballs  byes  legbyes wicket_type player_dismissed  over
# 0    NaN      NaN   NaN      NaN         NaN              NaN     1
# 1    NaN      NaN   NaN      NaN         NaN              NaN     1
# 2    NaN      NaN   NaN      NaN         NaN              NaN     1
# 3    1.0      NaN   NaN      NaN         NaN              NaN     1
# 4    1.0      NaN   NaN      NaN         NaN              NaN     1
# 5    NaN      1.0   NaN      NaN         NaN              NaN     1
# 6    NaN      NaN   NaN      NaN         NaN              NaN     1
# 7    NaN      NaN   NaN      NaN         NaN              NaN     1
# 8    NaN      NaN   NaN      NaN         NaN              NaN     1
# 9    NaN      NaN   NaN      NaN         NaN              NaN     2

# %%
allmatch_df.columns
# Out:
# Index(['match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes',
#        'wicket_type', 'player_dismissed', 'over'],
#       dtype='object')

# %%
#rearrange the columns
allmatch_df=allmatch_df[['match_id', 'season', 'start_date', 'venue', 'innings','over','ball',
                          'batting_team','bowling_team','striker', 'non_striker','runs_off_bat','extras',
                          'bowler','wicket_type','player_dismissed','wides', 'noballs', 'byes', 'legbyes']]

# %%
allmatch_df.head(10)
# Out:
#    match_id  season  start_date       venue  innings  over  ball batting_team  \
# 0   1229326    2020  2020-08-29  Chelmsford        1     1   0.1    Sunrisers
# 1   1229326    2020  2020-08-29  Chelmsford        1     1   0.2    Sunrisers
# 2   1229326    2020  2020-08-29  Chelmsford        1     1   0.3    Sunrisers
# 3   1229326    2020  2020-08-29  Chelmsford        1     1   0.4    Sunrisers
# 4   1229326    2020  2020-08-29  Chelmsford        1     1   0.5    Sunrisers
# 5   1229326    2020  2020-08-29  Chelmsford        1     1   0.6    Sunrisers
# 6   1229326    2020  2020-08-29  Chelmsford        1     1   0.7    Sunrisers
# 7   1229326    2020  2020-08-29  Chelmsford        1     1   0.8    Sunrisers
# 8   1229326    2020  2020-08-29  Chelmsford        1     1   0.9    Sunrisers
# 9   1229326    2020  2020-08-29  Chelmsford        1     2   1.1    Sunrisers
#
#       bowling_team     striker non_striker  runs_off_bat  extras     bowler  \
# 0  Southern Vipers  KL Midwood     AD Carr             0       0    LK Bell
# 1  Southern Vipers  KL Midwood     AD Carr             0       0    LK Bell
# 2  Southern Vipers  KL Midwood     AD Carr             0       0    LK Bell
# 3  Southern Vipers  KL Midwood     AD Carr             0       1    LK Bell
# 4  Southern Vipers  KL Midwood     AD Carr             0       1    LK Bell
# 5  Southern Vipers  KL Midwood     AD Carr             0       1    LK Bell
# 6  Southern Vipers  KL Midwood     AD Carr             0       0    LK Bell
# 7  Southern Vipers  KL Midwood     AD Carr             0       0    LK Bell
# 8  Southern Vipers  KL Midwood     AD Carr             0       0    LK Bell
# 9  Southern Vipers     AD Carr  KL Midwood             0       0  TG Norris
#
#   wicket_type player_dismissed  wides  noballs  byes  legbyes
# 0         NaN              NaN    NaN      NaN   NaN      NaN
# 1         NaN              NaN    NaN      NaN   NaN      NaN
# 2         NaN              NaN    NaN      NaN   NaN      NaN
# 3         NaN              NaN    1.0      NaN   NaN      NaN
# 4         NaN              NaN    1.0      NaN   NaN      NaN
# 5         NaN              NaN    NaN      1.0   NaN      NaN
# 6         NaN              NaN    NaN      NaN   NaN      NaN
# 7         NaN              NaN    NaN      NaN   NaN      NaN
# 8         NaN              NaN    NaN      NaN   NaN      NaN
# 9         NaN              NaN    NaN      NaN   NaN      NaN

# %%
#export the dataframe to csv file
allmatch_df.to_csv("C:\\Users\\DELL\\Cricdata\\allmatches_tidy.csv",index=False)

# %% [markdown]
# Finally two dataframes were taken into consideration for analysis, one containg the summary information of every match (match_summary) and the other contained ball by ball information (allmatch_df).
